# %% [markdown]
# # Demo Notebook
#
# This notebook is rendered by **reflex-jupyter-renderer-react**.
# It exercises markdown, code, stream output, an execute result and an error.

# %%
import numpy as np
print('Hello from a code cell!')
# Out:
# Hello from a code cell!

# %% [markdown]
# ## A computed value
# The next cell returns the mean of an array.

# %%
np.mean([1, 2, 3, 4, 5])
# Out:
# np.float64(3.0)

# %%
1 / 0
# Out:
# Traceback (most recent call last):
# ZeroDivisionError: division by zero
